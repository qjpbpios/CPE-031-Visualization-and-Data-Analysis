# %% [markdown]
# <a href="https://colab.research.google.com/github/qjpbpios/CPE-031-Visualization-and-Data-Analysis/blob/main/Hands_On_Activity_11___Storyboarding_Your_Data_Story_Pios_%26_Reyes%2C_Jazmin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 11 | Storyboarding Your Data Story**
#
#
#
#
#
# ---

# %% [markdown]
# Name : Pios, Joshua Paul B. | Reyes, Jazmin C. <br>
# Course Code and Title : CPE 031 | Visualizations and Data Analysis <br>
# Date Submitted : November 13, 2025<br>
# Instructor : Engr. Maria Rizette Sayo
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to help students demonstrate the ability to plan and visualize a simple data story using a storyboard approach, combining storytelling elements with visual thinking before coding full visualizations.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Analyze a dataset and identify the key message or insight.
#
# 2. Organize a logical flow for storytelling using a storyboard structure.
#
# 3. Create a simple storyboard visualization in Python.

# %% [markdown]
# **3. Discussions:**
#
# Storyboarding helps plan how your data story will unfold just like scenes in a movie.
# It helps you decide what charts, annotations, or visuals are needed to communicate your message effectively.
#
# A typical storyboard has:
#
# Frame 1: Title or question (What are we exploring?)
#
# Frame 2: Key data visualization or comparison
#
# Frame 3: Main insight or conclusion
#
# In Python, you can simulate a storyboard using multiple subplots each representing a scene or frame in your story.

# %% [markdown]
# **4. Procedures:**

# %% [markdown]
# Storyboard Example – “Sales Growth Over Time”

# %%
# Import libraries
import matplotlib.pyplot as plt

# Sample data
years = [2020, 2021, 2022, 2023, 2024]
sales = [100, 150, 200, 300, 450]

# Create storyboard using subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Frame 1: Title / Introduction
axes[0].text(0.5, 0.5, "Our Sales Journey\n(2020–2024)", ha='center', va='center', fontsize=14)
axes[0].axis("off")

# Frame 2: Key Data Visualization
axes[1].plot(years, sales, marker='o', color='steelblue')
axes[1].set_title("Sales Over Time")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Sales (in units)")

# Frame 3: Insight / Message
axes[2].text(0.5, 0.5, "Insight:\nSales grew steadily,\nwith a big jump after 2022!",
             ha='center', va='center', fontsize=12, color='darkgreen')
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# 1. Choose a small dataset (e.g., from Kaggle or manually created).
# Then, create a 3-frame storyboard in Python showing:
#
# Frame 1: Title or question
#
# Frame 2: One simple chart (bar or line)
#
# Frame 3: Main message or conclusion
#
# 2. Use matplotlib and label each part clearly.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {'Category': ['A', 'B', 'C', 'D', 'E'],
        'Values': [25, 40, 30, 55, 45]}
df = pd.DataFrame(data)

#Storyboard using subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5)) # Increased figsize for better readability

# Frame 1: Title / Introduction
axes[0].text(0.5, 0.5, "Analyzing Sample Data", ha='center', va='center', fontsize=16)
axes[0].axis("off")

# Frame 2: Key Data Visualization (Bar Chart)
axes[1].bar(df['Category'], df['Values'], color='skyblue')
axes[1].set_title("Values by Category")
axes[1].set_xlabel("Category")
axes[1].set_ylabel("Values")
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

# Frame 3: Insight / Message
max_category = df.loc[df['Values'].idxmax()]
axes[2].text(0.5, 0.5, f"Insight:\nCategory '{max_category['Category']}' has the highest value ({max_category['Values']}).",
             ha='center', va='center', fontsize=14, color='darkred', wrap=True) # Added wrap=True for long text
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# Doing this activity really helped us learn how to plan out telling a story with data, kind of like making a comic book but with charts instead of drawings. We, figured out how to take some data and show what's interesting about it using three simple pictures. The first one was like a title, the second showed a basic graph, and the last one explained what we learned from the graph, like which thing was the biggest. Using Python to make these little picture frames made it easy to see how each part helps tell the data's story clearly. It's cool to see how planning with these simple steps makes showing data way easier and helps make sure people get the main point you're trying to make.
